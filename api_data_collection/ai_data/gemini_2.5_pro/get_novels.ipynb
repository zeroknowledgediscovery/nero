# %%
import json
import regex as re 
import requests 
import sys
import pathlib
import os
import time

utils_dir = pathlib.Path.cwd().parent
sys.path.append(str(utils_dir)+"\\")
import utils
import natsort
import threading
import math

import numpy as np
from google import genai
from google.genai.types import *

# %%
genai_client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# %%
with open(utils_dir / r"topics.json","r") as in_json:
    topics = json.load(in_json)

model = "google/gemini-2.5-pro"

interaction_info = {}
context_window = 190000
max_completion_length = 8192
novel_desired_length = 150000
num_novels = 1000
chapter_length = 15000
#per minute
RPM_limit = 2000
ITPM_limit = 800000
OTPM_limit = 160000
requests_sent = 0
itokens = 0
otokens = 0
spend_limit = 1000.0
itoken_cost = 1.25
otoken_cost = 10.0


error_js_name = "error.json"
text_out_dir = r"generated_text"
thread_pause_semaphore = threading.Semaphore(1)

gemini_config = GenerateContentConfig(max_output_tokens=max_completion_length)
def request_anthropic(prompt, model, max_tokens=chapter_length):
    
    
    print("request posted")
    response = genai_client.models.generate_content(model=model,contents=prompt,config=gemini_config)
    print("request returned")
    
    itokens = response.usage_metadata.prompt_token_count
    otokens = response.usage_metadata.candidates_token_count
    text =  response.text
    print(text[:200])

    if response.candidates[0].finish_reason == FinishReason.STOP:
        print(f"request returned")
        return response.to_json_dict(),text,itokens,otokens
    else:
        print(f"Error: {response.candidates[0].finishReason}, {response.text}")
        raise Exception("invalid stop reason")


def check_for_error(response, error_js_name):
    if(response["choices"][0]["finish_reason"]!= "stop"):
        print(f"invalid stop reason: {response["choices"][0]["finish_reason"]}")
        json.dump(response, error_js_name)
        sys.exit()

# %%
metadata_out_dir = "metadata"
interaction_info = {}
if(not text_out_dir in os.listdir()):
    os.mkdir(text_out_dir)
    
files = utils.get_all_files_with_extension(f"{os.getcwd()}\\{metadata_out_dir}",".json")
files = natsort.natsorted(files)
print(f"files: {files}")
for file in files:
    with open(f"{os.getcwd()}\\{metadata_out_dir}\\{file}","r") as infile:
        interaction_info = json.load(infile)
    text = interaction_info["novel_text"]
    
    index = int(re.search("(\d+)",os.path.basename(file)).group(0))
    with open(f"{os.getcwd()}\\{text_out_dir}\\claude_sonnet{index}.txt","w",encoding="utf-8") as outfile:
        outfile.write(text)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\7ross\AppData\Local\Temp\ipykernel_156800\1678562341.py:13: SyntaxWarning: invalid escape sequence '\d'
#   index = int(re.search("(\d+)",os.path.basename(file)).group(0))
# files: ['metadata0.json', 'metadata1.json', 'metadata2.json', 'metadata3.json', 'metadata4.json', 'metadata5.json', 'metadata6.json', 'metadata7.json', 'metadata8.json', 'metadata9.json', 'metadata10.json', 'metadata11.json', 'metadata12.json', 'metadata13.json', 'metadata14.json', 'metadata15.json', 'metadata16.json', 'metadata17.json', 'metadata18.json', 'metadata19.json', 'metadata20.json', 'metadata21.json', 'metadata22.json', 'metadata23.json', 'metadata24.json', 'met
# %%
skip_indices = []
itokens = 0
otokens = 0
requests_sent = 0
itokens_semaphore = threading.Semaphore(1)
otokens_semaphore = threading.Semaphore(1)
requests_sent_semaphore = threading.Semaphore(1)
cost_dict = {}
if(os.path.exists("cost.json")):
    with open("cost.json","r") as infile:
        cost_dict = json.load(infile)
else:
    cost_dict["total_cost"] = 0
    cost_dict["total_itokens"] = 0
    cost_dict["total_otokens"] = 0
    with open("cost.json","w")as outfile:
        json.dump(cost_dict,outfile)
def update_cost_metadata(itokens, otokens):
    cost_dict["total_itokens"] += itokens
    cost_dict["total_otokens"] += otokens
    print(f"million itokens: {cost_dict["total_itokens"]/1000000.0}, estimated cost: {(cost_dict["total_itokens"]/1000000.0)*itoken_cost}")
    print(f"million otokens: {cost_dict["total_otokens"]/1000000.0}, estimated cost: {(cost_dict["total_otokens"]/1000000.0)*otoken_cost}")
    cost_dict["total_cost"] = ((cost_dict["total_itokens"]/1000000.0)*itoken_cost)+((cost_dict["total_otokens"]/1000000.0)*otoken_cost)
    with open("cost.json","w") as outfile:
        json.dump(cost_dict,outfile)
    if(cost_dict["total_cost"]>1000.0):
        return False
    else:
        return True

def check_rate_limits():
        #will block all other threads from generating until the calling thread is done waiting out the rate limiting
        global itokens
        global otokens
        global requests_sent
        with thread_pause_semaphore:
            if(itokens>ITPM_limit or otokens>OTPM_limit or requests_sent>RPM_limit):
                time.sleep(70)
                itokens = 0
                otokens = 0
                requests_sent = 0

@utils.multithreading
def generate_novel(topic:str,index:int) -> None:
    interaction_info = {}
    metadata_path = f"{os.getcwd()}\\{metadata_out_dir}\\metadata{index}.json"
    global itokens 
    global otokens 
    global requests_sent
    
    
    if(index in skip_indices):
        print(f"novel index is in skipped indices: {index}")
        return

    if(not os.path.exists(metadata_path)):
        interaction_info["novel_text"] = ""
        interaction_info["responses"] = []
    else:
        print(f"found metadata at path {metadata_path}")
        with open(metadata_path,"r") as infile:
            interaction_info = json.load(infile)    
    

    novel_current_length = len(interaction_info["novel_text"])
    first_prompt = f"I want you to act as a novelist writing about {topic}. The total length of the novel is about {novel_desired_length} characters and after generating each section of the novel i will tell you how much of the text you have generated so far. Try to generate text with some irregularities in order to fool ai detection software. In the novel you should include plot points characters dialogue and an overall plot. Generate only the text for this novel and do not add any annotations. Pace the plot and story according to the current number of characters I tell you. Generate the text in full paragraphs and chapters of about {chapter_length} character length. Continue generating chapter 1 until I tell you to stop. Generate EXCLUSIVELY novel text with no annotations confirmations or listing the chapter number."
    
    
    while(len(interaction_info["novel_text"])<novel_desired_length):
        prompt = ""
        if(novel_current_length == 0):
            prompt = first_prompt
        else:
            prompt = interaction_info["novel_text"] + f"Here is the previous generated text. You have generated {novel_current_length} characters so far. Generate chapter {math.floor(novel_current_length/chapter_length)+1} until i tell you to stop, also remember to generate text in complete paragraphs and do not generate lines with a single sentence. Generate EXCLUSIVELY novel text"
            
            if(len(prompt)+max_completion_length>context_window):
                prompt = prompt[len(prompt)-(context_window-max_completion_length)::]
        check_rate_limits() 
        try: 
            response,text,itk,otk = request_anthropic(prompt,model,max_tokens=max_completion_length)
        except Exception as err:
            print(f"request anthropic error catch:\n{err}")
            return err
        with requests_sent_semaphore:
            requests_sent += 1 
            
        
        with itokens_semaphore:
            itokens += itk
            
        with otokens_semaphore:
            otokens += otk
            

        with itokens_semaphore,otokens_semaphore:
            if(not update_cost_metadata(itk,otk)):
                print(f"cost limit hit")
                sys.exit()
            
        interaction_info["responses"].append(response)
        try:
            interaction_info["novel_text"] += text
        except Exception as err:
            print(f"value errors from trying to get the text:\n{err}")
            return err
        novel_current_length += len(text)
        print(f"current novel: {index}")
        print(f"response text length: {len(text)}")
        print(f"total novel length: {novel_current_length}")
        print(f"preview: \n{text[:500]}")
        with open(metadata_path,"w") as outfile:
           json.dump(interaction_info,outfile,indent = 5) 

        if(otk < 200):
            print(f"adding {index} to skipped indices")
            skip_indices.append(index)
            return None
    return None

# %%
def is_written(index:int) -> bool:
    metadata_path = f"{os.getcwd()}\\{text_out_dir}\\metadata{index}.json"
    if(os.path.exists(metadata_path)):
        interaction_info = {}
        with open(metadata_path,"r") as infile:
            interaction_info = json.load(infile)
        
        if(len(interaction_info["novel_text"])>=novel_desired_length):
            return True
        else:
            if(index in skip_indices):
                return True
            else:
                return False
    else:
        return False

def is_generation_finished():
    files = utils.get_all_files_with_extension(f"{os.getcwd()}\\{text_out_dir}",".json")
    files = natsort.natsorted(files)
    for file in files:
        index = int(re.search("(\d+)",os.path.basename(file)).group(0))
        if(not is_written(index)):
            return False



if(os.path.exists(f"{os.getcwd()}\\skip_indices.json")):
    with open(f"{os.getcwd()}\\skip_indices.json","r") as infile:
        skip_indices = json.load(infile)
for novel_index in range(num_novels):
    if(not is_written(novel_index)):
        topic = topics[novel_index]
        err = generate_novel(topic,novel_index)
        while(err != None):
            print("restarting generation")
            time.sleep(10)
            err = generate_novel(topic,novel_index)
        with open(f"{os.getcwd()}\\skip_indices.json","w") as outfile:
            json.dump(skip_indices,outfile)
    else:
        print(f"skipping index: {novel_index}")
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\d'
# <>:22: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\7ross\AppData\Local\Temp\ipykernel_156800\1995077815.py:22: SyntaxWarning: invalid escape sequence '\d'
#   index = int(re.search("(\d+)",os.path.basename(file)).group(0))
# skipping index: 0
# skipping index: 1
# skipping index: 2
# skipping index: 3
# skipping index: 4
# skipping index: 5
# skipping index: 6
# skipping index: 7
# skipping index: 8
# skipping index: 9
# skipping index: 10
# skipping index: 11
# skipping index: 12
# skipping index: 13
# skipping index: 14
# skipping index: 15
# skipping index: 16
# skipping index: 17
# skipping index: 18
# skipping index: 19
# skipping index: 20
# request returned
# million itokens: 348.928831, estimated cost: 436.16103875
# million otokens: 33.964801, estimated cost: 339.64801
# current novel: 913
# response text length: 8155
# total novel length: 48980
# preview:
# The fifteen-mile drive east from Inverness to Nairn followed the coastline, the grey expanse of the Moray Firth a constant, brooding presence to their left. Fraser drove this time, his earlier, twitchy energy having subsided into a grim, focused silence. He was learning. The initial shock was being replaced by the dull, heavy armour of professional necessity. Gash sat beside him, watching the landscape shift from industrial estates to rolling farmland and then to the neat, stone-built houses of
# request posted
# request returned
# The forty-eight-hour deadline imposed by the Cease and Desist letter was a ticking clock in the back of Eleanor’s mind, but she refused to let it govern her. Instead, she retreated into her work with
# request returned
# million itokens: 348.956019, estimated cost: 436.19502375
# million otokens: 33.966371, estimated cost: 339.66371000000004
# current novel: 832
# response text length: 7361
# total novel length: 129904
# preview:
# The forty-eight-hour deadline imposed by the Cease and Desist letter was a ticking clock in the back of Eleanor’s mind, but she refused to let it govern her. Instead, she retreated into her work with the grim determination of a soldier digging a trench under fire. The small study became her command bunker. She worked with an almost monastic discipline, her world shrinking to the glowing rectangle of her monitor, the complex latticework of her editing timeline, and the comforting hiss of her head
# request posted
# request returned
# The drive back from Nairn was a silent, grim procession. The beauty of the coastline, the white-capped waves rolling onto the sand, the vast, open sky – it all seemed like a mockery, a painted backdro
# request returned
# million itokens: 348.967352, estimated cost: 436.20919000000004
# million otokens: 33.967781, estimated cost: 339.67781
# current novel: 913
# response text length: 6144
# total novel length: 55124
# preview:
# The drive back from Nairn was a silent, grim procession. The beauty of the coastline, the white-capped waves rolling onto the sand, the vast, open sky – it all seemed like a mockery, a painted backdrop for a scene of profound human ugliness. Gash stared out at the water, but he wasn’t seeing it. He was seeing the two portraits, side by side in his mind’s eye. Morven Ross, lost in the ecstasy of her music; Liam Robertson, exploding with the joy of youth. Cormac Croft had not chosen his subjects a
# request posted
# request returned
# The email from the *Today* programme was not a letter, it was a crossroads. Eleanor sat staring at the screen, the calm, intelligent prose of Jamila Chowdhury’s invitation feeling more dangerous than
# request returned
# million itokens: 348.99611, estimated cost: 436.2451375
# million otokens: 33.969946, estimated cost: 339.69946
# current novel: 832
# response text length: 10202
# total novel length: 140106
# preview:
# The email from the *Today* programme was not a letter, it was a crossroads. Eleanor sat staring at the screen, the calm, intelligent prose of Jamila Chowdhury’s invitation feeling more dangerous than any legal threat she had yet received. The lawyers wanted to silence her by burying her in debt and procedure. The media, even in this respectable guise, offered a different kind of annihilation: to be consumed by her own story, to be flattened back into a two-dimensional character for public consum
# request posted
# request returned
# The sound of Gash’s fist connecting with the laminated particleboard of his desk was a gunshot in the cathedral quiet of the incident room. It was a raw, percussive crack of splintering wood and bruis
# request returned
# million itokens: 349.008853, estimated cost: 436.26106625
# million otokens: 33.971802, estimated cost: 339.71801999999997
# current novel: 913
# response text length: 8084
# total novel length: 63208
# preview:
# The sound of Gash’s fist connecting with the laminated particleboard of his desk was a gunshot in the cathedral quiet of the incident room. It was a raw, percussive crack of splintering wood and bruised knuckles that cut through the low hum of keyboards and hushed phone calls, silencing everything. Every head in the room snapped towards him. In that sudden, profound stillness, Gash was the epicentre, a monolith of barely contained violence. He stood frozen for a half-second, his own knuckles thr
# request posted
# request returned
# The journey back from London was an exercise in deliberate disconnection. Eleanor sat on the train, her forehead pressed against the cool glass of the window, and watched the blur of the suburbs give
# request returned
# million itokens: 349.039777, estimated cost: 436.29972125
# million otokens: 33.974111, estimated cost: 339.74111
# current novel: 832
# response text length: 10305
# total novel length: 150411
# preview:
# The journey back from London was an exercise in deliberate disconnection. Eleanor sat on the train, her forehead pressed against the cool glass of the window, and watched the blur of the suburbs give way to the green fields of Hertfordshire. She did not open her phone. She did not check for reactions or messages. She had stepped out of the river of noise and now, on its banks, she needed a moment of stillness before she could even begin to assess whether she had been carried to safety or swept f
# request returned
# The Kessock Bridge rose before them, a harp of steel and cable strung across the dark waters of the Beauly Firth. The lights of Inverness dwindled behind them, a smear of gold and white against the br
# request returned
# million itokens: 349.054376, estimated cost: 436.31797
# million otokens: 33.975579, estimated cost: 339.75579000000005
# current novel: 913
# response text length: 6561
# total novel length: 69769
# preview:
# The Kessock Bridge rose before them, a harp of steel and cable strung across the dark waters of the Beauly Firth. The lights of Inverness dwindled behind them, a smear of gold and white against the bruised purple of the twilight sky. Ahead lay the Black Isle, a looming mass of shadow, its familiar silhouette now seeming alien and menacing. Rain lashed against the windscreen, the wipers beating a frantic, hypnotic rhythm that did little to soothe the tension inside the car. For Gash, this crossin
# request posted
# request returned
# Gash stepped over the threshold, his boots sinking into the soft bed of wood shavings that carpeted the floor. The scent was overpowering, a holy trinity of the killer’s world: the sharp, resinous per
# request returned
# million itokens: 349.070443, estimated cost: 436.33805375000003
# million otokens: 33.976917, estimated cost: 339.76917000000003
# current novel: 913
# response text length: 5928
# total novel length: 75697
# preview:
# Gash stepped over the threshold, his boots sinking into the soft bed of wood shavings that carpeted the floor. The scent was overpowering, a holy trinity of the killer’s world: the sharp, resinous perfume of freshly worked pine, the acrid bite of turpentine, and the faint, sweet, coppery tang of death. Fraser followed a step behind, a pale spectre with a trembling handgun, his gaze fixed on the serene, white-bearded man lying in state. But Gash’s eyes were locked on Cormac Croft. He saw the flic
# request posted
# request returned
# The journey back from the Black Isle was a descent into a new kind of silence. The frantic, hunting quiet of the drive out had been replaced by the dead, sterile quiet of a specimen in a jar. Fraser d
# request returned
# million itokens: 349.087848, estimated cost: 436.35981000000004
# million otokens: 33.979153, estimated cost: 339.79152999999997
# current novel: 913
# response text length: 9912
# total novel length: 85609
# preview:
# The journey back from the Black Isle was a descent into a new kind of silence. The frantic, hunting quiet of the drive out had been replaced by the dead, sterile quiet of a specimen in a jar. Fraser drove, his hands locked on the wheel, his eyes fixed on the rain-swept road ahead as if it were the only solid thing in a world that had dissolved into madness. Gash sat in the back with Cormac Croft. The killer was cuffed, his hands in his lap, but he sat with an easy, untroubled posture, his gaze d
# request posted
# request returned
# The pre-dawn light was not the familiar ink of possibility anymore; it was the colour of a day-old bruise. Gash stood on the floating pontoon of the rowing club, the air cold and still, the silence pr
# request returned
# million itokens: 349.107489, estimated cost: 436.38436125
# million otokens: 33.98111, estimated cost: 339.8111
# current novel: 913
# response text length: 8551
# total novel length: 94160
# preview:
# The pre-dawn light was not the familiar ink of possibility anymore; it was the colour of a day-old bruise. Gash stood on the floating pontoon of the rowing club, the air cold and still, the silence profound. But it was no longer his silence. It was a shared silence, occupied by the ghost of Cormac Croft. He ran a hand over the smooth, cold hull of ‘The Morrigan’, his fingers tracing the contours of the carbon fibre as if it were the face of a stranger. The familiar pre-row ritual, the checking o
# request posted
# request returned
# For a long time, Sergeant Gash simply stared at the blue folder. It was an object of profound, almost offensive, banality. The corners were soft and frayed, a coffee ring had stained the top right cor
# request returned
# million itokens: 349.129087, estimated cost: 436.41135875000003
# million otokens: 33.982998, estimated cost: 339.82998000000003
# current novel: 913
# response text length: 8312
# total novel length: 102472
# preview:
# For a long time, Sergeant Gash simply stared at the blue folder. It was an object of profound, almost offensive, banality. The corners were soft and frayed, a coffee ring had stained the top right corner, and the handwritten label was a messy, indifferent scrawl. Inside, the typed words were a litany of the mundane: one diesel generator, three nail guns, a Kango hammer, assorted power tools. The estimated value was a few thousand pounds. The crime scene was a muddy, half-finished building site o
# request posted
# request returned
# The hours bled into one another, each one marked only by the changing light outside the station windows and the growing pile of discarded coffee cups on Gash’s desk. The incident room, having solved i
# request returned
# million itokens: 349.152574, estimated cost: 436.4407175
# million otokens: 33.984644, estimated cost: 339.84644000000003
# current novel: 913
# response text length: 7071
# total novel length: 109543
# preview:
# The hours bled into one another, each one marked only by the changing light outside the station windows and the growing pile of discarded coffee cups on Gash’s desk. The incident room, having solved its grand, terrible puzzle, had largely moved on. Detectives spoke of other cases, other lives, their voices a low, normal hum that felt alien to Gash. He was an island, a man marooned in the glow of his monitor. On the screen, the grainy, two-second loop played relentlessly. Tap. Tap. Tap. A ghost’s
# request posted
# request returned
# The silence in the car on the way back from Merkinch was a dead weight, heavier and more suffocating than the tense quiet of the hunt. Fraser, in the driver’s seat, was practically vibrating with the
# request returned
# million itokens: 349.177707, estimated cost: 436.47213375
# million otokens: 33.986352, estimated cost: 339.86352
# current novel: 913
# response text length: 7537
# total novel length: 117080
# preview:
# The silence in the car on the way back from Merkinch was a dead weight, heavier and more suffocating than the tense quiet of the hunt. Fraser, in the driver’s seat, was practically vibrating with the low-frequency hum of a job well done. He had caught the scent of a clean, simple victory and was basking in it, the satisfaction rolling off him in palpable waves. He cleared his throat, unable to contain it any longer, his voice bright with a professional pride that felt like sandpaper on Gash’s ra
# request posted
# request returned
# He didn’t go back to the station. He walked out into the grey, spitting rain of the afternoon and got into his car, the engine turning over with a tired, familiar rumble. He drove without thinking, hi
# request returned
# million itokens: 349.204548, estimated cost: 436.50568499999997
# million otokens: 33.987981, estimated cost: 339.87980999999996
# current novel: 913
# response text length: 6833
# total novel length: 123913
# preview:
# He didn’t go back to the station. He walked out into the grey, spitting rain of the afternoon and got into his car, the engine turning over with a tired, familiar rumble. He drove without thinking, his hands guiding the wheel through the city traffic by muscle memory alone, his mind a grey, featureless fog. He bypassed the turn-off for his flat, his gaze fixed on the road ahead as if he could outrun the question that Dr. Morrison had hung around his neck like a millstone. He found himself on the
# request posted
# request returned
# He did not drive home. He drove back to the station, the sterile blue-white lights of the car park a beacon in the deepening gloom. The building was quieter now, the day shift having given way to the
# request returned
# million itokens: 349.233018, estimated cost: 436.5412725
# million otokens: 33.989376, estimated cost: 339.89376
# current novel: 913
# response text length: 6087
# total novel length: 130000
# preview:
# He did not drive home. He drove back to the station, the sterile blue-white lights of the car park a beacon in the deepening gloom. The building was quieter now, the day shift having given way to the skeleton crew of the night. Their faces were fresher, their energy less frayed, and they looked at him with a mixture of awe and morbid curiosity as he passed. He was the man who had walked into the forest and come back with the monster, a figure from a grim fairy tale that was now part of the stati
# request posted
# request returned
# Gash became a machine. In the days that followed his grim epiphany on the water, he processed the petty miseries of Inverness with a relentless, mechanical efficiency. His desk became a churn, taking
# request returned
# million itokens: 349.262883, estimated cost: 436.57860374999996
# million otokens: 33.990982, estimated cost: 339.90982
# current novel: 913
# response text length: 7438
# total novel length: 137438
# preview:
# Gash became a machine. In the days that followed his grim epiphany on the water, he processed the petty miseries of Inverness with a relentless, mechanical efficiency. His desk became a churn, taking in raw data—witness statements on vandalism, CCTV footage of shoplifters, forensics reports from pub brawls—and spitting out completed, cross-referenced case files. He was the first in the station and the last to leave, a great, silent engine of police work running in the corner of the office. The d
# request posted
# request returned
# The incident room felt different this time. The frenetic, adrenaline-fueled energy of the Croft investigation, with its lurid portraits and visceral horror, was gone. In its place was a quieter, more
# request returned
# million itokens: 349.294355, estimated cost: 436.61794375
# million otokens: 33.992894, estimated cost: 339.92894
# current novel: 913
# response text length: 8647
# total novel length: 146085
# preview:
# The incident room felt different this time. The frenetic, adrenaline-fueled energy of the Croft investigation, with its lurid portraits and visceral horror, was gone. In its place was a quieter, more cerebral tension. The whiteboard was no longer a canvas for a serial killer’s art show; it was a blank page waiting for a story to be pieced together from missing fragments. At its centre was a passport photo of Simon Barrow, a man with thin, pursed lips, intelligent but unforgiving eyes behind seve
# request posted
# request returned
# The drive south to Edinburgh was a long, grey ribbon of motorway, a modern artery laid over an ancient, wounded landscape. Gash sat in the passenger seat, silent, watching the rolling hills of the Cai
# request returned
# million itokens: 349.327739, estimated cost: 436.65967375
# million otokens: 33.994928, estimated cost: 339.94928000000004
# current novel: 913
# response text length: 9576
# total novel length: 155661
# preview:
# The drive south to Edinburgh was a long, grey ribbon of motorway, a modern artery laid over an ancient, wounded landscape. Gash sat in the passenger seat, silent, watching the rolling hills of the Cairngorms give way to the gentler farmland of Perthshire. He was not admiring the scenery. He was mapping the crime in his head, seeing it not as a single point of violence, but as a sprawling, interconnected territory of motive and opportunity. He was moving from the 'what' to the 'who', a journey th
