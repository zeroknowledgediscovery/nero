# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile
from selenium.webdriver.common.by import By
import time
import regex as re
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import ElementClickInterceptedException



import sys,os
import re
import json

# %%
# this only exists to throw the novel topics into a giant list and then a json file

topics = []

options = Options()
firefox_profile = FirefoxProfile()
firefox_profile.set_preference("javascript.enabled", True)
options.profile = firefox_profile


t_driver = webdriver.Firefox(options=options)
t_driver.install_addon("uBlock0_1.64.1b8.firefox.signed.xpi")
t_driver.get("https://www.plot-generator.org.uk/story-ideas/")
time.sleep(3)

# %%
def get_topics(driver,topics_list):
    num_topic_element = t_driver.find_element(By.XPATH,"//input[@class='sizeTiny']")
    num_topic_element.clear()
    num_topic_element.send_keys("20")

    generate_button = t_driver.find_element(By.XPATH,"//input[@value = 'Write me a list of story ideas']")
    generate_button = t_driver.find_element(By.XPATH,"//input[@value = 'Write me a list of story ideas']")
    generate_button.click()

    topics = driver.find_elements(By.CLASS_NAME,"random_story")
    for topic in topics:
        clean_topic = re.sub("[\d\n]+","",topic.text)
        print(clean_topic)
        topics_list.append(clean_topic)
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\7ross\AppData\Local\Temp\ipykernel_118072\2337653085.py:12: SyntaxWarning: invalid escape sequence '\d'
#   clean_topic = re.sub("[\d\n]+","",topic.text)

# %%
topic_num = 1000
json_name = "topics.json"

while(len(topics)<topic_num):
    get_topics(t_driver,topics)
    with open(json_name,"w") as outfile:
        json.dump(topics,outfile,indent = 1)
# Out:
# Tallulah is a giant fuelled by regret, who taunts women and blogs about it. Doctor Salgado, an electrician from Dallas, knows she has to stop her. In one final act of destruction, the villian orchestrates a mass murder, and kills  women is one attack.
# A pilot from Bournemouth is delighted when he gets the chance to take part in the final of a pie eating contest. However, his chances are scuppered when his supper is spiked. After the drama, the pilot realises there is more to life than winning a pie eating contest and goes on to have a happy, rounded life..
# When an orphan from San Juan learns how to turn invisible, not everybody is supportive. However, her fortunes improve when her teacher buys a record company. After achieving her goal, the orphan turns to gambling then is killed by mobsters.
# ...
